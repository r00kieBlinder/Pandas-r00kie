# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create a quick DataFrame
my_df = pd.DataFrame(randn(100, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   1.196740 -0.032494 -1.109835  0.627975
# 1  -0.298743 -1.950117 -0.338609  0.408909
# 2  -0.637283  0.387116 -1.189252  2.184101
# 3   0.645031 -0.694681 -0.960435 -0.843258
# 4   0.991570 -1.196578  0.687853  0.931815
# ..       ...       ...       ...       ...
# 95 -1.426972  0.171764  1.111713  0.355754
# 96 -0.203535 -0.287239 -0.113520 -0.342834
# 97 -0.149152 -1.256919 -0.592964 -1.303941
# 98  0.151979  0.181416  0.110992  1.979527
# 99  0.123138 -0.008754  0.231071 -1.507389
#
# [100 rows x 4 columns]

# %%
# Area Plot
my_df.abs().plot(kind='area')
# Out:
# <Axes: >

# %%
# Set the Shading 
my_df.abs().plot(kind='area', alpha=0.5)
# Out:
# <Axes: >

# %%
# Add a title to area plot
my_df.abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot!")
# Out:
# <Axes: title={'center': 'My Awesome Area Plot!'}>

# %%
# Add/Remove legend 
my_df.abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot!", legend=False)
# Out:
# <Axes: title={'center': 'My Awesome Area Plot!'}>

# %%
# Plot only 1 column
my_df["Mon"].abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot!", legend=False)
# Out:
# <Axes: title={'center': 'My Awesome Area Plot!'}>

# %%
# Plot more than one column
my_df[["Mon", "Thur"]].abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot!", legend=False)
# Out:
# <Axes: title={'center': 'My Awesome Area Plot!'}>

# %%
# Get info on function - Shift + Tab

# %%
# Add table 
my_df.abs().plot(kind='area', alpha=0.5, title="My Awesome Area Plot!", legend=False, table=True)
# Out:
# <Axes: title={'center': 'My Awesome Area Plot!'}>
