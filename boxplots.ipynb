# %%
import pandas as pd 
import numpy as np
from numpy.random import randn
# %matplotlib inline 

# Create DataFrame
my_df = pd.DataFrame(randn(500, 4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -1.671410 -0.277977 -0.057080 -0.362117
# 1    0.314167  0.505889  0.422342 -1.157468
# 2   -0.013841  1.017317 -0.837065 -0.268445
# 3    0.433231 -1.418706  1.214022 -0.159344
# 4    1.400276 -1.105088  0.512549 -0.560133
# ..        ...       ...       ...       ...
# 495  0.034145 -0.696442  0.323839 -0.512311
# 496  0.879355  1.192091  0.753411  0.446698
# 497 -0.205712  0.907616  0.656913  0.284437
# 498 -0.001471  0.291045 -0.920278  0.562538
# 499  1.812227 -3.299520 -0.703614  1.181183
#
# [500 rows x 4 columns]

# %%
# Boxplot
my_df.plot(kind="box")
# Out:
# <Axes: >

# %%
# Boxplots Size
my_df.plot(kind="box", figsize=(10, 7))
# Out:
# <Axes: >

# %%
# Boxplot color : https://matplotlib.org/stable/users/explain/colors/colormaps.html
my_df.plot(kind="box", cmap="hsv")
# Out:
# <Axes: >

# %%
# No Legend
my_df.plot(kind="box", legend=True)
# Out:
# <Axes: >

# %%
# Title 
my_df.plot(kind="box", title="My Awesome Box Plot!")
# Out:
# <Axes: title={'center': 'My Awesome Box Plot!'}>

# %%
# Other Way
my_df.plot.box()
# Out:
# <Axes: >

# %%
# Adding Grid 
my_df.plot.box(title="My Awesome Box Chart!", grid=True)
# Out:
# <Axes: title={'center': 'My Awesome Box Chart!'}>
