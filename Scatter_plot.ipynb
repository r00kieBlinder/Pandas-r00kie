# %%
import pandas as pd 
import numpy as np
from numpy.random import randn
# %matplotlib inline 

# Create DataFrame
my_df = pd.DataFrame(randn(500, 4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -0.459288 -1.118236 -0.126568 -1.160902
# 1    0.913253 -0.287870  1.970262  2.164535
# 2   -1.058507  1.843323 -0.565963 -0.424871
# 3    1.549267  0.990928  1.591666 -0.284833
# 4    1.544243  0.268678 -0.162022  0.641359
# ..        ...       ...       ...       ...
# 495 -0.731413 -1.663147 -1.177699  0.416457
# 496 -1.740269  2.525363 -1.345794  0.726122
# 497  0.510461 -0.541971 -0.417245 -1.357851
# 498  0.314040  1.672202 -0.619751 -1.600028
# 499  0.769934 -0.733030 -1.035074 -1.715474
#
# [500 rows x 4 columns]

# %%
# Scatter plot
my_df.plot(kind="scatter", x='Mon', y='Tues', c='Wed')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Colors : https://matplotlib.org/stable/users/explain/colors/colormaps.html
my_df.plot(kind="scatter", x='Mon', y='Tues', c='Wed', cmap="magma")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Size
my_df.plot(kind="scatter", x='Mon', y='Tues', s=my_df['Wed']*100)
# Out:
# /Users/fahimabrar/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Size easier to read with Alpha 
my_df.plot(kind="scatter", x='Mon', y='Tues', s=my_df['Wed']*200, alpha=0.3)
# Out:
# /Users/fahimabrar/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title
my_df.plot(kind="scatter", x='Mon', y='Tues', s=my_df['Wed']*200, alpha=0.3, title="My Awesome Scatter Plot")
# Out:
# /Users/fahimabrar/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: title={'center': 'My Awesome Scatter Plot'}, xlabel='Mon', ylabel='Tues'>
