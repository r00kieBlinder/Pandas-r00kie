# %%
import pandas as pd 
import numpy as np
from numpy.random import randn
# %matplotlib inline 

# Create DataFrame
my_df = pd.DataFrame(randn(500, 4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    1.685910  0.860242 -0.909031  1.829499
# 1   -1.633966 -1.812140  0.072675  0.758461
# 2    0.838932  1.419146 -1.212164  0.322009
# 3   -1.414124  1.182206  0.869102  2.010204
# 4   -0.138349 -1.411836 -0.466343  0.650725
# ..        ...       ...       ...       ...
# 495 -0.286734 -0.756174  1.063511  0.733296
# 496  0.739214  0.065022 -0.452616  0.364311
# 497  0.178378 -0.028438  2.869422  1.738200
# 498 -0.435546 -0.700003  0.784735 -0.629088
# 499 -0.406890  0.288796 -0.320218 -0.247429
#
# [500 rows x 4 columns]

# %%
# Hexplots
my_df.plot(kind="hexbin", x='Mon', y='Tues')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplot gridsize
my_df.plot(kind="hexbin", x='Mon', y='Tues', gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplot color
my_df.plot(kind="hexbin", x='Mon', y='Tues', gridsize=10, cmap="Greens")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Other Method 
my_df.plot.hexbin(x='Mon', y='Tues', C='Wed', gridsize=10, cmap="Greens")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title 
my_df.plot.hexbin(x='Mon', y='Tues', C='Wed', gridsize=10, cmap="Greens", title="My Awesome Hex Plots!")
# Out:
# <Axes: title={'center': 'My Awesome Hex Plots!'}, xlabel='Mon', ylabel='Tues'>

# %%
# Grid 
my_df.plot.hexbin(x='Mon', y='Tues', C='Wed', gridsize=10, cmap="Greens", title="My Awesome Hex Plots!", grid=True)
# Out:
# <Axes: title={'center': 'My Awesome Hex Plots!'}, xlabel='Mon', ylabel='Tues'>
