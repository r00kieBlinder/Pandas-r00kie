# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create a quick DataFrame
my_df = pd.DataFrame(randn(100, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   0.258021 -0.554823 -0.232700  1.764634
# 1  -1.428599 -0.357489  1.812841  1.175235
# 2  -1.186968 -0.528589  0.403023  0.838256
# 3  -0.154930 -1.055405  0.694741  1.360382
# 4   0.747594 -1.131083 -1.829644 -0.765827
# ..       ...       ...       ...       ...
# 95 -0.066129 -0.520933 -0.676276 -1.724147
# 96 -0.459366  0.772095 -0.654066 -0.554987
# 97  0.037974  0.941900  0.065389 -1.734272
# 98 -0.870505  1.060344  0.848887 -0.550320
# 99  1.801496 -1.165743 -0.110999 -0.461718
#
# [100 rows x 4 columns]

# %%
# Histograms
my_df["Wed"].hist()
# Out:
# <Axes: >

# %%
# Histograms with smaller bins, 50, 20 
my_df["Wed"].hist(bins=20)
# Out:
# <Axes: >

# %%
# Another way without the grid bars 
my_df["Wed"].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
my_df["Wed"].hist(bins=20, grid=True, legend=True)
# Out:
# <Axes: >
