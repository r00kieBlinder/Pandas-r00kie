# %%
import pandas as pd 
import numpy as np
from numpy.random import randn
# %matplotlib inline 

# Create DataFrame
my_df = pd.DataFrame(randn(50, 4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#          Mon      Tues       Wed     Thurs
# 0   0.397036  0.225238  1.207710  0.452881
# 1  -0.452506  0.211644 -2.592500 -0.844535
# 2   0.740983 -0.372281  2.417228 -0.579333
# 3  -1.825565 -1.463571 -0.043843  0.777915
# 4   1.971708  0.618992  0.435679 -0.445510
# 5   1.440710 -0.831175 -2.234225  0.897023
# 6   1.102795  0.269065 -0.841510 -1.284328
# 7   0.558364  1.022782  0.805090  0.117284
# 8   0.339190  0.752598  0.249416 -2.052712
# 9   0.099302  0.302184  0.326980 -0.680653
# 10  0.232887  0.783912  0.791304  0.262492
# 11 -0.770267 -0.937568 -0.669862  0.654652
# 12 -1.146117 -0.466708 -0.149945  2.147861
# 13  0.124881  0.527241 -1.884401 -0.034048
# 14  0.124674 -0.282305 -1.691045  0.976458
# 15 -0.023968 -2.167034 -1.171688 -1.521354
# 16  0.329121  0.060969  2.366936  1.064757
# 17 -0.432336  1.037145  0.926299  1.613242
# 18  0.660969 -0.727214 -0.614180  2.080589
# 19  0.653611 -0.259541 -0.877494 -0.093629
# 20  0.347543 -0.378170  2.283201  0.284044
# 21  0.760706  1.862866  0.940501  0.362092
# 22 -1.899872  1.022891 -0.560832 -0.225346
# 23 -0.158632 -1.020769  0.422322  0.648806
# 24  0.377980  0.423705  0.082978  0.562024
# 25  0.042641 -0.187153  0.474828  0.207172
# 26 -1.844765  1.784774  1.168675 -0.716122
# 27  2.244459  0.869427 -1.928156  1.620815
# 28 -0.794378 -0.734343 -0.253998  0.775671
# 29 -0.360067  1.377303  0.606208 -0.386761
# 30  0.303182 -0.576446  2.498836 -0.284536
# 31 -0.353171  1.146002 -0.472100 -0.325853
# 32 -0.826163 -0.528762  1.151389  0.479359
# 33 -0.743805  0.868186  0.666650  0.515187
# 34  2.162486 -0.186439  0.597860  1.005281
# 35 -0.974471  0.372722 -1.407831 -0.988256
# 36 -0.031485  0.304504 -1.154602  0.439205
# 37  1.003272  1.260790 -1.241180  1.592709
# 38 -0.728157  1.967962  0.896112 -0.642307
# 39 -0.909712 -1.535030  0.662848  0.677118
# 40  1.110687  0.557261 -0.164305 -0.191252
# 41  1.166904 -0.482830 -0.822889 -1.039686
# 42  0.064290  0.450297  0.761458  1.633862
# 43 -0.544356  0.053007  0.578235  1.749203
# 44  1.475288  1.257682  0.403020 -0.153311
# 45  0.040210 -0.048663  0.097878 -0.418127
# 46 -1.068251  1.965147 -0.715276  0.679840
# 47 -1.706718  0.620506  1.064928 -2.536212
# 48  0.526339  0.134856  0.841305 -0.363551
# 49 -1.617269 -0.155023 -1.667101  1.098930

# %%
# Scatter plot
my_df.plot(kind="scatter", x='Mon', y='Tues', c='Wed')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Colors : https://matplotlib.org/stable/users/explain/colors/colormaps.html
my_df.plot(kind="scatter", x='Mon', y='Tues', c='Wed', cmap="magma")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Size
my_df.plot(kind="scatter", x='Mon', y='Tues', s=my_df['Wed']*100)
# Out:
# /Users/fahimabrar/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Size easier to read with Alpha 
my_df.plot(kind="scatter", x='Mon', y='Tues', s=my_df['Wed']*200, alpha=0.3)
# Out:
# /Users/fahimabrar/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='Mon', ylabel='Tues'>
