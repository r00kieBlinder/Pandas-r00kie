# %%
import pandas as pd 
import numpy as np
from numpy.random import randn
# %matplotlib inline 

# Create DataFrame
my_df = pd.DataFrame(randn(500, 4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.475478 -0.309551 -0.227391  0.561817
# 1   -0.032779  0.995055 -0.227037  0.758665
# 2    0.360258  0.125541  0.143031  0.544367
# 3    0.768194  1.239086  0.536083 -0.836909
# 4    0.676696 -0.482684 -0.602651 -0.958479
# ..        ...       ...       ...       ...
# 495  1.709038  0.679766 -0.631754  1.384506
# 496 -0.787420 -0.601388 -0.337964 -0.709177
# 497 -0.830476  1.426996  0.810759  2.318077
# 498 -0.507695 -0.423428  0.446912 -0.900780
# 499 -2.334700 -0.351348  0.970827  2.557266
#
# [500 rows x 4 columns]

# %%
# Density and Kernal Density Estimation plots with scipy library 
my_df.plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
# KDE second way to learn shift tab 
my_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
# Density plot 
my_df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
# Other way 
my_df.plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
# Change stuff
my_df["Mon"].plot(kind="density", alpha=0.6, cmap="magma", lw=4)
# Out:
# <Axes: ylabel='Density'>

# %%
# title & grid
my_df.plot(kind="kde", title="My Awesome KDE plot!", grid=True)
# Out:
# <Axes: title={'center': 'My Awesome KDE plot!'}, ylabel='Density'>
